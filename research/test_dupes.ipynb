# %% [markdown]
# ### Testing Dupes
# Wanted to see if old entries had duplicated entries for starttime/bike_id

# %%
import pandas as pd

df = pd.read_csv(
    "/Users/patrickcleary/Downloads/2013-citibike-tripdata/201306-citibike-tripdata.csv"
)

# %%
df[df.duplicated(subset=['starttime', 'bikeid'], keep=False)]
# Out:
#         tripduration            starttime             stoptime  \
# 2925            1087  2013-06-01 13:29:52  2013-06-01 13:47:59
# 2927            1112  2013-06-01 13:29:52  2013-06-01 13:48:24
# 42486            412  2013-06-04 18:02:47  2013-06-04 18:09:39
# 42487            430  2013-06-04 18:02:47  2013-06-04 18:09:57
# 44163            923  2013-06-04 18:56:58  2013-06-04 19:12:21
# 44164          48179  2013-06-04 18:56:58  2013-06-05 08:19:57
# 50063           1122  2013-06-05 08:53:11  2013-06-05 09:11:53
# 50064          34752  2013-06-05 08:53:11  2013-06-05 18:32:23
# 126930          1223  2013-06-11 17:01:51  2013-06-11 17:22:14
# 126933          1216  2013-06-11 17:01:51  2013-06-11 17:22:07
# 290956          1732  2013-06-20 16:32:27  2013-06-20 17:01:19
# 290957          1724  2013-06-20 16:32:27  2013-06-20 17:01:11
#
#         start station id  start station name  start station latitude  \
# 2925                 514    12 Ave & W 40 St               40.760875
# ...
